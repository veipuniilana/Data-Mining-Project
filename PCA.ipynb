# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Ground_Water_Data\\ground_water_quality_in_assam-2014.csv",
                encoding = "unicode_escape")
data.head(2)
# Out:
#    STATION CODE                         LOCATIONS  STATE  \
# 0          1533  *DIGBOI, TINSUKIA DISTT.,  ASSAM  Assam
# 1          1534     *KARBI  ANGLONG DISTT., ASSAM  Assam
#
#    TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  TEMPERATURE ºC : Mean  \
# 0                  23.0                    24                   23.5
# 1                  23.0                    24                   23.5
#
#    pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  pH : Mean : 6.5-8.5  \
# 0                 6.4                 6.6                  6.5
# 1                 6.2                 6.5                  6.4
#
#    CONDUCTIVITY (µmhos/cm) : Min  ...  B.O.D. (mg/l) : Mean : < 3 mg/l  \
# 0                            734  ...                              1.4
# 1                            205  ...                              1.1
#
#    NITRATE- N+ NITRITE-N (mg/l) : Min  NITRATE- N+ NITRITE-N (mg/l) : Max  \
# 0                                 5.4                                 8.6
# 1                                 0.2                                 1.2
#
#    NITRATE- N+ NITRITE-N (mg/l) : Mean  \
# 0                                  7.0
# 1                                  0.7
#
#    FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                                  0
# 1                                                  0
#
#    FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                                 36
# 1                                                150
#
#    FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                                 18
# 1                                                 75
#
#    TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  \
# 0                                                  0
# 1                                                  0
#
#    TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                              24000
# 1                                              11000
#
#    TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml
# 0                                              12000
# 1                                               5500
#
# [2 rows x 24 columns]

# %%
values = data.drop(["STATION CODE","LOCATIONS","STATE"],axis =1)
values.head()
# Out:
#    TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  TEMPERATURE ºC : Mean  \
# 0                  23.0                    24                   23.5
# 1                  23.0                    24                   23.5
# 2                  24.0                    25                   24.5
# 3                  20.0                    25                   22.5
# 4                  24.0                    25                   24.5
#
#    pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  pH : Mean : 6.5-8.5  \
# 0                 6.4                 6.6                  6.5
# 1                 6.2                 6.5                  6.4
# 2                 6.4                 7.5                  7.0
# 3                 5.5                 5.8                  5.7
# 4                 6.6                 7.4                  7.0
#
#    CONDUCTIVITY (µmhos/cm) : Min  CONDUCTIVITY (µmhos/cm) : Max  \
# 0                            734                            762
# 1                            205                            470
# 2                            302                            364
# 3                            696                            885
# 4                            440                            579
#
#    CONDUCTIVITY (µmhos/cm) : Mean  B.O.D. (mg/l) : Min : < 3 mg/l  ...  \
# 0                             748                             0.7  ...
# 1                             338                             0.7  ...
# 2                             333                             0.9  ...
# 3                             791                             1.3  ...
# 4                             510                             1.1  ...
#
#    B.O.D. (mg/l) : Mean : < 3 mg/l  NITRATE- N+ NITRITE-N (mg/l) : Min  \
# 0                              1.4                                 5.4
# 1                              1.1                                 0.2
# 2                              1.4                                 0.3
# 3                              1.9                                 0.1
# 4                              2.2                                 2.4
#
#    NITRATE- N+ NITRITE-N (mg/l) : Max  NITRATE- N+ NITRITE-N (mg/l) : Mean  \
# 0                                 8.6                                  7.0
# 1                                 1.2                                  0.7
# 2                                 0.7                                  0.5
# 3                                 0.4                                  0.3
# 4                                 3.8                                  3.1
#
#    FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                 36
#
#    FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                                 36
# 1                                                150
# 2                                                  0
# 3                                                  0
# 4                                                 72
#
#    FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                                 18
# 1                                                 75
# 2                                                  0
# 3                                                  0
# 4                                                 54
#
#    TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  \
# 0                                                  0
# 1                                                  0
# 2                                                 91
# 3                                                  0
# 4                                               2100
#
#    TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                              24000
# 1                                              11000
# 2                                                 91
# 3                                                 91
# 4                                               4600
#
#    TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml
# 0                                              12000
# 1                                               5500
# 2                                                 91
# 3                                                 46
# 4                                               3350
#
# [5 rows x 21 columns]

# %%
corr = values.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(20,20))
g = sns.heatmap(corr,
            vmin=-1,
            cmap='coolwarm',
            annot=True,
            mask = mask);
plt.savefig("corr.png")

# %% [markdown]
# As is obvious from the given correlation graph, we see that the features are quiet independent of each other, barring the ones that desciribe the same variable. By performing PCA, we will be able to condense the information given to us into fewer meaningful variables.

# %% [markdown]
# Now, we'll be performing PCA on all of the data.

# %% [markdown]
# # Data Preprocessing - Principal Component Analysis
# Principal component analysis (PCA) is a statistical procedure which converts a set of observations of possibly correlated variables into a set of values of linearly uncorrelated variables called principal components..<br><br>
# In this notebook, we use PCA to reduce the dimensions of the ground water dataset.<br>
# We start by importing the necessary libraries and loading the dataset into the notebook.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Ground_Water_Data\ground_water_quality_in_kerala-2014.csv",
                encoding = "unicode_escape")
df.head()
# Out:
#    STATION CODE                                 LOCATIONS   STATE  \
# 0            19                     WELL AT ELOOR, KERALA  Kerala
# 1            22               WELL AT CHUNGAPALLY, KERALA  Kerala
# 2            35                   WELL AT PUNALUR, KERALA  Kerala
# 3          1581  PAPPANAMKODE, THIRUVANANTHAPURAM, KERALA  Kerala
# 4          1582    NEDUMANGAD, THIRUVANANTHAPURAM, KERALA  Kerala
#
#    TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  TEMPERATURE ºC : Mean  \
# 0                  27.4                  27.5                   27.5
# 1                  24.0                  26.0                   25.0
# 2                  24.0                  24.0                   24.0
# 3                  25.0                  26.5                   25.8
# 4                  25.0                  26.5                   25.8
#
#    pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  pH : Mean : 6.5-8.5  \
# 0                 5.2                 7.2                  6.2
# 1                 5.7                 7.7                  6.7
# 2                 4.8                 7.2                  6.0
# 3                 6.0                 6.8                  6.4
# 4                 7.0                 7.4                  7.2
#
#    CONDUCTIVITY (µmhos/cm) : Min  ...  B.O.D. (mg/l) : Mean : < 3 mg/l  \
# 0                            137  ...                              1.0
# 1                            103  ...                              0.4
# 2                            170  ...                              0.6
# 3                            296  ...                              1.3
# 4                            150  ...                              4.0
#
#    NITRATE- N+ NITRITE-N (mg/l) : Min  NITRATE- N+ NITRITE-N (mg/l) : Max  \
# 0                                1.96                                3.31
# 1                                0.42                                1.30
# 2                                0.81                                0.84
# 3                                0.00                                2.30
# 4                                1.20                                4.20
#
#    NITRATE- N+ NITRITE-N (mg/l) : Mean  \
# 0                                  2.6
# 1                                  0.9
# 2                                  0.8
# 3                                  1.2
# 4                                  2.7
#
#    FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                                 79
# 1                                                 17
# 2                                                 43
# 3                                                 79
# 4                                                 43
#
#    FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                                220
# 1                                                350
# 2                                                280
# 3                                                110
# 4                                                 94
#
#    FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                                150
# 1                                                184
# 2                                                162
# 3                                                 95
# 4                                                 69
#
#    TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  \
# 0                                                110
# 1                                                 22
# 2                                                110
# 3                                                220
# 4                                                180
#
#    TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                                630
# 1                                                430
# 2                                                430
# 3                                                350
# 4                                                240
#
#    TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml
# 0                                                370
# 1                                                226
# 2                                                270
# 3                                                285
# 4                                                210
#
# [5 rows x 24 columns]

# %% [markdown]
# Only features on which it is meaningful to use PCA on are selected.

# %%
data = df.drop(['STATION CODE','LOCATIONS','STATE'], axis=1)
data.head()
# Out:
#    TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  TEMPERATURE ºC : Mean  \
# 0                  27.4                  27.5                   27.5
# 1                  24.0                  26.0                   25.0
# 2                  24.0                  24.0                   24.0
# 3                  25.0                  26.5                   25.8
# 4                  25.0                  26.5                   25.8
#
#    pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  pH : Mean : 6.5-8.5  \
# 0                 5.2                 7.2                  6.2
# 1                 5.7                 7.7                  6.7
# 2                 4.8                 7.2                  6.0
# 3                 6.0                 6.8                  6.4
# 4                 7.0                 7.4                  7.2
#
#    CONDUCTIVITY (µmhos/cm) : Min  CONDUCTIVITY (µmhos/cm) : Max  \
# 0                            137                            180
# 1                            103                            125
# 2                            170                            220
# 3                            296                            412
# 4                            150                            170
#
#    CONDUCTIVITY (µmhos/cm) : Mean  B.O.D. (mg/l) : Min : < 3 mg/l  ...  \
# 0                             159                             0.8  ...
# 1                             114                             0.2  ...
# 2                             195                             0.6  ...
# 3                             354                             1.0  ...
# 4                             160                             1.0  ...
#
#    B.O.D. (mg/l) : Mean : < 3 mg/l  NITRATE- N+ NITRITE-N (mg/l) : Min  \
# 0                              1.0                                1.96
# 1                              0.4                                0.42
# 2                              0.6                                0.81
# 3                              1.3                                0.00
# 4                              4.0                                1.20
#
#    NITRATE- N+ NITRITE-N (mg/l) : Max  NITRATE- N+ NITRITE-N (mg/l) : Mean  \
# 0                                3.31                                  2.6
# 1                                1.30                                  0.9
# 2                                0.84                                  0.8
# 3                                2.30                                  1.2
# 4                                4.20                                  2.7
#
#    FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                                 79
# 1                                                 17
# 2                                                 43
# 3                                                 79
# 4                                                 43
#
#    FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                                220
# 1                                                350
# 2                                                280
# 3                                                110
# 4                                                 94
#
#    FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                                150
# 1                                                184
# 2                                                162
# 3                                                 95
# 4                                                 69
#
#    TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  \
# 0                                                110
# 1                                                 22
# 2                                                110
# 3                                                220
# 4                                                180
#
#    TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                                630
# 1                                                430
# 2                                                430
# 3                                                350
# 4                                                240
#
#    TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml
# 0                                                370
# 1                                                226
# 2                                                270
# 3                                                285
# 4                                                210
#
# [5 rows x 21 columns]

# %% [markdown]
# ##  Normalising the data -

# %%
#we implement normalisation using the z metric using the value (x-u)/sigma
def normalize_data(data):
    mu = np.mean(data, 0)
    sigma = np.std(data, 0)
    data_norm = (data-mu)/sigma
    return data_norm, mu, sigma

# %%
data_norm, mu, sigma = normalize_data(data)
data_norm.head()
# Out:
#    TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  TEMPERATURE ºC : Mean  \
# 0              0.272599             -0.221863               0.031817
# 1             -1.734561             -1.007629              -1.391577
# 2             -1.734561             -2.055316              -1.960935
# 3             -1.144220             -0.745707              -0.936091
# 4             -1.144220             -0.745707              -0.936091
#
#    pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  pH : Mean : 6.5-8.5  \
# 0           -0.852026            0.314506            -0.414531
# 1           -0.349094            0.999967             0.214668
# 2           -1.254372            0.314506            -0.666210
# 3           -0.047335           -0.233863            -0.162851
# 4            0.958530            0.588691             0.843866
#
#    CONDUCTIVITY (µmhos/cm) : Min  CONDUCTIVITY (µmhos/cm) : Max  \
# 0                      -0.481964                      -0.507795
# 1                      -0.724098                      -0.750344
# 2                      -0.246952                      -0.331396
# 3                       0.650369                       0.515318
# 4                      -0.389384                      -0.551895
#
#    CONDUCTIVITY (µmhos/cm) : Mean  B.O.D. (mg/l) : Min : < 3 mg/l  ...  \
# 0                       -0.508453                        0.254982  ...
# 1                       -0.759723                       -1.422965  ...
# 2                       -0.307437                       -0.304334  ...
# 3                        0.580385                        0.814298  ...
# 4                       -0.502869                        0.814298  ...
#
#    B.O.D. (mg/l) : Mean : < 3 mg/l  NITRATE- N+ NITRITE-N (mg/l) : Min  \
# 0                        -0.184101                            0.211863
# 1                        -0.252015                           -0.801208
# 2                        -0.229377                           -0.544651
# 3                        -0.150144                           -1.077500
# 4                         0.155470                           -0.288094
#
#    NITRATE- N+ NITRITE-N (mg/l) : Max  NITRATE- N+ NITRITE-N (mg/l) : Mean  \
# 0                           -0.142137                            -0.043102
# 1                           -0.825714                            -0.902175
# 2                           -0.982155                            -0.952708
# 3                           -0.485626                            -0.750574
# 4                            0.160542                             0.007431
#
#    FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                           0.042153
# 1                                          -0.477486
# 2                                          -0.259573
# 3                                           0.042153
# 4                                          -0.259573
#
#    FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                          -0.156070
# 1                                           0.221506
# 2                                           0.018195
# 3                                          -0.475558
# 4                                          -0.522029
#
#    FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                          -0.111568
# 1                                           0.045715
# 2                                          -0.056056
# 3                                          -0.365996
# 4                                          -0.486271
#
#    TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  \
# 0                                          -0.318263
# 1                                          -0.670423
# 2                                          -0.318263
# 3                                           0.121938
# 4                                          -0.038135
#
#    TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                           0.065824
# 1                                          -0.233175
# 2                                          -0.233175
# 3                                          -0.352775
# 4                                          -0.517224
#
#    TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml
# 0                                          -0.041570
# 1                                          -0.376871
# 2                                          -0.274418
# 3                                          -0.239491
# 4                                          -0.414127
#
# [5 rows x 21 columns]

# %% [markdown]
# ## PCA comprises of the following  steps -
# 1) Calculate the covariance matrix<br>
# 2) Obtain the eigenvectors and eigenvalues corresponding to the covariance matrix<br>
# 3) Using the eigenvectors correspongind to the k largest eigenvaleus to construct the principal components <br>
# 4) Project the data onto the principal components to get the compressed dataset<br>

# %% [markdown]
# ## Step 1: Calculate the covariance matrix -

# %%
cov_mat = np.cov(data_norm.transpose())
print(cov_mat.shape)
#print(cov_mat)
# Out:
# (21, 21)

# %% [markdown]
# ## Step 2: Compute eigenvectors and eigenvalues of the covariance matrix -

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
print(eig_vecs.shape)
#print(eig_vals)
#print(eig_vecs)
# Out:
# (21, 21)

# %% [markdown]
# ## Step 3: Construct the principal components

# %% [markdown]
# To choose the number of eigenvectors we are using, we  can utilize a scree plot.<br>
# For the other datasets, eigenvectors corresponding to eigenvalues greater than will be chosen.

# %%
index = np.arange(1,eig_vals.shape[0]+1)
import seaborn as sns
sns.pointplot(x=index, y=eig_vals).set_title("Scree Plot")
# Out:
# Text(0.5, 1.0, 'Scree Plot')

# %% [markdown]
# An elbow is seen at 6  components on the x-axis. Using 6 components, the explained variance is:

# %%
print(np.sum(eig_vals[0:6]/np.sum(eig_vals)))
# Out:
# 0.901280265173478

# %%
print(np.sum(eig_vals>1)*1)
# Out:
# 6

# %% [markdown]
# Making a matrix of only the first 6 eigenvectors

# %%
eig_vecs = eig_vecs[:,0:6]
eig_vecs.shape
# Out:
# (21, 6)

# %% [markdown]
# ## Step 5: Project the data onto the new compressed space

# %%
Y_pca = data_norm.dot(eig_vecs)
print(data_norm.shape)
# Out:
# (34, 21)

# %% [markdown]
# As we can see, we have transformed the original dataset which was 34x21 to one which is 34x6!

# %% [markdown]
# For convenience the following function will be used to perform PCA on the data of the remaining states -

# %%
 def pca(data):
    data_norm,mu,sigma = normalize_data(data)
    cov_mat = np.cov(data_norm.transpose())
    eig_vals, eig_vecs = np.linalg.eig(cov_mat)
    n = np.sum(eig_vals>1)*1

    
    eig_vecs = eig_vecs[:,0:n]
    Y_pca = data_norm.dot(eig_vecs)
    return Y_pca

# %%
pca(data_norm)
# Out:
#            0         1         2         3         4         5
# 0  -0.002517  0.886812 -0.159971 -0.239243 -0.446805 -0.183853
# 1   1.144131  1.972697  2.223529  0.453587 -0.450619  0.082444
# 2   1.123785  2.709839  2.107992  0.269000  1.163080  0.725423
# 3   1.313990  0.353769  1.175282  0.564365  1.516171  0.582125
# 4   1.303213  0.598026  1.014326 -0.149687  0.588747 -1.766330
# 5   2.283585  5.015117  0.815366  0.007260  1.610989  2.504142
# 6   1.074414 -1.125584  1.303536  1.923000 -2.046681 -0.704203
# 7   0.252157 -2.958610 -0.445071 -1.329630  0.600681 -1.814888
# 8   0.761869  0.324315 -1.832895 -2.582913  0.366297  0.836919
# 9  -1.029713 -0.977665 -1.565111 -3.989032  0.058247 -1.544170
# 10 -0.263503 -2.198925  0.785604  1.417901 -1.001048 -1.074480
# 11  2.089490 -1.281476 -0.590690  0.993453 -1.704129  0.767655
# 12  0.469827  1.582033  1.323428  0.268327 -0.877293  0.002108
# 13  0.861792  1.403579 -2.431472 -0.872881 -1.581182  0.580267
# 14  1.714990  0.267147 -0.506073 -0.086864 -1.500244  0.021343
# 15 -7.419431 -1.028542  1.098933 -0.063995 -0.043886  0.206256
# 16 -5.659880  1.223503  0.685534  1.663972 -0.620887  0.408863
# 17 -5.145818  0.716015  1.217711  0.963148 -0.148613  0.278266
# 18 -2.162127  0.911806 -0.539512 -2.463699 -0.454827 -0.278215
# 19 -0.130324 -1.696912  1.912570  2.273261 -0.862081 -0.982339
# 20  0.156570  2.026379  1.946616 -0.365470  2.110558 -0.833509
# 21  2.316004 -1.369131  3.091139 -0.314952  3.827558 -1.871153
# 22  1.112613  2.814363 -1.228984  0.454728 -0.908411  0.970524
# 23  0.918480  0.140116 -1.774704 -2.487255  0.579782  0.364867
# 24  1.536720 -0.659033 -0.907206  0.107968 -1.749127  0.711607
# 25 -1.391312 -1.847868 -1.358557 -0.365420 -0.671821 -0.668019
# 26 -0.837252  1.177691 -6.898256  4.335005  3.234064 -1.230925
# 27 -4.795926  0.188554  0.051315 -1.352041  1.170541  0.733953
# 28  2.346484  0.105738  0.147495  1.076923 -1.170497 -0.725939
# 29  0.038772 -5.699283 -0.095928  0.687507  1.128624  3.456212
# 30 -0.217321  1.312964 -0.039991 -0.344541 -1.411032  0.478099
# 31  2.518175 -5.437897  0.231415 -0.102339  1.324486  1.938919
# 32  1.868800 -1.019922 -0.257602 -0.119821 -1.220049 -1.527958
# 33  1.849264  1.570387 -0.499766 -0.229623 -0.410592 -0.444013

# %% [markdown]
# Now, to perform PCA on the entire dataset

# %%
data_norm.dtypes
# Out:
# TEMPERATURE ºC : Min                                    float64
# TEMPERATURE ºC : Max                                    float64
# TEMPERATURE ºC : Mean                                   float64
# pH : Min : 6.5-8.5                                      float64
# pH : Max : 6.5-8.5                                      float64
# pH : Mean : 6.5-8.5                                     float64
# CONDUCTIVITY (µmhos/cm) : Min                           float64
# CONDUCTIVITY (µmhos/cm) : Max                           float64
# CONDUCTIVITY (µmhos/cm) : Mean                          float64
# B.O.D. (mg/l) : Min : < 3 mg/l                          float64
# B.O.D. (mg/l) : Max : < 3 mg/l                          float64
# B.O.D. (mg/l) : Mean : < 3 mg/l                         float64
# NITRATE- N+ NITRITE-N (mg/l) : Min                      float64
# NITRATE- N+ NITRITE-N (mg/l) : Max                      float64
# NITRATE- N+ NITRITE-N (mg/l) : Mean                     float64
# FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml     float64
# FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml     float64
# FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml    float64
# TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml     float64
# TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml     float64
# TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml    float64
# dtype: object

# %%
data = pd.read_csv("Ground_water_pre_processed\\filled_groundwater.csv")

# %%
states = data["STATE"]
values = data.drop(["STATION CODE","LOCATIONS","STATE"],axis =1)

# %%
temp = pca(values)

# %%
df_concat = pd.concat([states, temp], axis=1)

# %%
df_concat.groupby('STATE', as_index=False).mean()
# Out:
#                    STATE         0         1         2         3         4  \
# 0         ANDHRA PRADESH  0.923023 -0.939194  1.197476  1.042797  0.206376
# 1                  Assam -0.384789  0.322737  0.433387  1.188265 -0.319719
# 2                  Bihar -0.067473  0.212513  0.875602  0.352443  0.115447
# 3           CHHATTISGARH -0.837175  0.700139  0.337825  0.702517  0.016165
# 4           Chhattisgarh -0.783732  0.876605 -0.143490 -0.108426 -0.016748
# 5   DADRA & NAGAR HAVELI -0.635144  0.754237 -0.747854 -0.604663 -0.278303
# 6            DAMAN & DIU  0.141048  0.525194 -1.262533 -0.738543 -0.370487
# 7                    Goa -1.192348  1.074873 -0.554499 -0.250505 -0.440606
# 8       HIMACHAL PRADESH  0.178256 -0.130433  1.306788  1.231293  0.225400
# 9                 KERALA -0.937256  0.924214 -0.404530  0.115548  0.077314
# 10                Kerala -0.910459  0.798471 -0.223996  0.735896 -0.384836
# 11           LAKSHADWEEP -2.451970 -2.992643 -0.204256 -0.099264  0.016180
# 12           Lakshadweep -2.763833 -2.433077 -1.036248 -1.490932  1.993440
# 13        Madhya Pradesh  0.705648 -0.376649 -0.954437  0.205192  0.144870
# 14           Maharashtra  0.886282 -0.187092 -1.477530  1.110850  0.247250
# 15                Odisha -1.659876 -1.065604 -0.932437 -0.056281 -0.245272
# 16           PONDICHERRY -0.492900  0.656823 -0.706865 -0.710306 -0.083137
# 17                PUNJAB  0.083586  0.088759 -0.191768  0.106180 -0.152575
# 18             Rajasthan  1.420701 -0.278709 -0.004039 -1.566531 -0.144467
# 19               TRIPURA -0.740313  0.550691  0.087848 -0.053005  0.209283
# 20         Uttar Pradesh  0.090763 -0.238275  0.429766 -0.063092 -0.057887
# 21           WEST BENGAL -0.733366  0.698364 -0.577007 -0.971838 -0.101725
#
#            5         6
# 0  -0.054315  0.274260
# 1   0.413904  1.340446
# 2   0.010354  0.252621
# 3   0.182132  0.183381
# 4  -0.087783  0.260327
# 5  -0.629729  0.449208
# 6  -0.561843  0.798794
# 7  -0.207007  1.022539
# 8   0.704165  0.152595
# 9  -0.056374 -0.068652
# 10 -0.128801  0.832856
# 11 -4.276185  1.911612
# 12 -0.231454  2.372895
# 13 -1.530020 -0.392278
# 14 -0.224839 -0.580207
# 15  0.546041 -0.485212
# 16 -0.810572 -0.456722
# 17  0.278799 -0.045449
# 18  0.124043 -0.353223
# 19 -0.743286 -1.164772
# 20  0.273871 -0.927340
# 21 -0.099751 -0.865082

# %%
df_concat.to_csv('PCA_All_states.csv')
